# %%
# %load_ext sql

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb
# Out:
# 'Connected: student@sparkifydb'

# %%
# %sql SELECT s.song_id, a.artist_id, a.name FROM songs AS s JOIN artists AS a ON s.artist_id = a.artist_id
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 71 rows affected.
# [('SOINLJW12A8C13314C', 'AR8IEZO1187B99055E', 'Marc Shaiman'),
#  ('SOGDBUF12A8C140FAA', 'AR558FS1187FB45658', '40 Grit'),
#  ('SORRZGD12A6310DBC3', 'ARVBRGZ1187FB4675A', 'Gwen Stefani'),
#  ('SONWXQJ12A8C134D94', 'ARNF6401187FB57032', 'Sophie B. Hawkins'),
#  ('SOFCHDR12AB01866EF', 'AREVWGE1187B9B890A', 'Bitter End'),
#  ('SONSKXP12A8C13A2C9', 'AR0IAWL1187B9A96D0', 'Danilo Perez'),
#  ('SODAUVL12A8C13D184', 'ARWB3G61187FB49404', 'Steve Morse'),
#  ('SOSWKAV12AB018FC91', 'ARULZCI1241B9C8611', 'Luna Orbit Project'),
#  ('SOLYIBD12A8C135045', 'AR051KA1187B98B2FF', 'Wilks'),
#  ('SOWQTQZ12A58A7B63E', 'ARPFHN61187FB575F6', 'Lupe Fiasco'),
#  ('SOUPIRU12A6D4FA1E1', 'ARJIE2Y1187B994AB7', 'Line Renaud'),
#  ('SODREIN12A58A7F2E5', 'ARLTWXK1187FB5A3F8', 'King Curtis'),
#  ('SOBCOSW12A8C13D398', 'AR7SMBG1187B9B9066', 'Los Manolos'),
#  ('SOFNOQK12AB01840FC', 'ARNNKDK1187B98BBD5', 'Jinx'),
#  ('SOXILUQ12A58A7C72A', 'ARP6N5A1187B99D1A3', 'Mitch Ryder'),
#  ('SOOJPRH12A8C141995', 'ARBGXIG122988F409D', 'Steel Rain'),
#  ('SOQOTLQ12AB01868D0', 'ARGCY1Y1187B9A4FA5', 'Gloriana'),
#  ('SOGVQGJ12AB017F169', 'AR62SOJ1187FB47BB5', 'Chase & Status'),
#  ('SOFFKZS12AB017F194', 'ARBEBBY1187B9B43DB', 'Tom Petty'),
#  ('SOTCKKY12AB018A141', 'ARGSAFR1269FB35070', 'Blingtones'),
#  ('SOBAYLL12A8C138AF9', 'ARDR4AC1187FB371A1', 'Montserrat Caballé;Placido Domingo;Vicente Sardinero;Judith Blegen;Sherrill Milnes;Georg Solti'),
#  ('SOLEYHO12AB0188A85', 'ARAGB2O1187FB3A161', 'Pucho & His Latin Soul Brothers'),
#  ('SOBKWDJ12A8C13B2F3', 'AR36F9J1187FB406F1', 'Bombay Rockers'),
#  ('SOPEGZN12AB0181B3D', 'AREDL271187FB40F44', 'Soul Mekanik'),
#  ('SOQLGFP12A58A7800E', 'ARD7TVE1187B99BFB1', 'Casual'),
#  ('SOMVWWT12A58A7AE05', 'ARQ9BO41187FB5CF1F', 'John Davis'),
#  ('SOSLAVG12A8C13397F', 'AROGWRA122988FEE45', 'Christos Dantis'),
#  ('SOQVMXR12A81C21483', 'ARKULSX1187FB45F84', 'Trafik'),
#  ('SOPVXLX12A8C1402D5', 'AR3JMC51187B9AE49D', 'Backstreet Boys'),
#  ('SODUJBS12A8C132150', 'ARI2JSK1187FB496EF', 'Nick Ingman;Gavyn Wright'),
#  ('SOBBXLX12A58A79DDA', 'AREDBBQ1187B98AFF5', 'Eddie Calvert'),
#  ('SOTUKVB12AB0181477', 'AR7ZKHQ1187B98DD73', 'Glad'),
#  ('SOAOIBZ12AB01815BE', 'ARPBNLO1187FB3D52F', 'Tiny Tim'),
#  ('SOZHPGD12A8C1394FE', 'AR9AWNF1187B9AB0B4', 'Kenny G featuring Daryl Hall'),
#  ('SOTTDKS12AB018D69B', 'ARMBR4Y1187B9990EB', 'David Martin'),
#  ('SOBLGCN12AB0183212', 'AR47JEX1187B995D81', 'SUE THOMPSON'),
#  ('SONYPOM12A8C13B2D7', 'ARDNS031187B9924F0', 'Tim Wilson'),
#  ('SOOLYAZ12A6701F4A6', 'AREBBGV1187FB523D2', "Mike Jones (Featuring CJ_ Mello & Lil' Bran)"),
#  ('SOPSWQW12A6D4F8781', 'ARGIWFO1187B9B55B7', 'Five Bolt Main'),
#  ('SOYTPEP12AB0180E7B', 'ARAJPHH1187FB5566A', 'The Shangri-Las'),
#  ('SOGXHEG12AB018653E', 'AR0RCMP1187FB3F427', 'Billie Jo Spears'),
#  ('SOVYKGO12AB0187199', 'ARH4Z031187B9A71F2', 'Faye Adams'),
#  ('SOGNCJP12A58A80271', 'ARB29H41187B98F0EF', 'Terry Callier'),
#  ('SOGOSOV12AF72A285E', 'ARGUVEV1187B98BA17', 'Sierra Maestra'),
#  ('SOLLHMX12AB01846DC', 'AR1Y2PT1187FB5B9CE', 'John Wesley'),
#  ('SOBZBAZ12A6D4F8742', 'AROUOZZ1187B9ABE51', 'Willie Bobo'),
#  ('SOZQDIU12A58A7BCF6', 'ARNTLGG11E2835DDB9', 'Clp'),
#  ('SOZCTXZ12AB0182364', 'AR5KOSW1187FB35FF4', 'Elena'),
#  ('SOBBUGU12A8C13E95D', 'ARMAC4T1187FB3FA4C', 'The Dillinger Escape Plan'),
#  ('SOUQQEA12A8C134B1B', 'ARIG6O41187B988BDD', 'Richard Souther'),
#  ('SOBONFF12A6D4F84D8', 'ARIK43K1187B9AE54C', 'Lionel Richie'),
#  ('SOXLBJT12A8C140925', 'ARYKCQI1187FB3B18F', 'Tesla'),
#  ('SOHUOAP12A8AE488E9', 'ARD842G1187B997376', 'Blue Rodeo'),
#  ('SOKEJEJ12A8C13E0D0', 'ARC43071187B990240', 'Wayne Watson'),
#  ('SOMUYGI12AB0188633', 'ARL7K851187B99ACD2', 'Andy Andy'),
#  ('SOZVMJI12AB01808AF', 'ARNPAGP1241B9C7FD4', 'lextrical'),
#  ('SOWTBJW12AC468AC6E', 'ARQGYP71187FB44566', 'Jimmy Wakely'),
#  ('SOILPQQ12AB017E82A', 'AR1ZHYZ1187FB3C717', 'Faiz Ali Faiz'),
#  ('SORAMLE12AB017C8B0', 'ARHHO3O1187B989413', 'Bob Azzam'),
#  ('SOBEBDG12A58A76D60', 'ARI3BMM1187FB4255E', 'Alice Stuart'),
#  ('SOXVLOJ12AB0189215', 'ARKRRTF1187B9984DA', 'Sonora Santanera'),
#  ('SOIAZJW12AB01853F1', 'AR8ZCNI1187B9A069B', 'Planet P Project'),
#  ('SOHKNRJ12A6701D1F8', 'AR10USD1187B99F3F1', 'Tweeterfriendly Music'),
#  ('SOUDSGM12AC9618304', 'ARNTLGG11E2835DDB9', 'Clp'),
#  ('SOFSOCN12A8C143F5D', 'ARXR32B1187FB57099', 'Gob'),
#  ('SOQHXMF12AB0182363', 'ARGSJW91187B9B1D6B', 'JennyAnyKind'),
#  ('SOMZWCG12A8C13C480', 'ARD7TVE1187B99BFB1', 'Casual'),
#  ('SONHOTT12A8C13493C', 'AR7G5I41187FB4CE6C', 'Adam Ant'),
#  ('SOMJBYD12A6D4F8557', 'ARD0S291187B9B7BF5', 'Rated R'),
#  ('SOYMRWW12A6D4FAB14', 'ARKFYS91187B98E58F', 'Jeff And Sheri Easter'),
#  ('SOCIWDW12A8C13D406', 'ARMJAGH1187FB546F3', 'The Box Tops')]

# %%
# %sql SELECT artist_id FROM artists WHERE 'AR8IEZO1187B99055E' = artist_id
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [('AR8IEZO1187B99055E',)]

# %%
# %sql SELECT * FROM songplays LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(1, datetime.datetime(2018, 11, 29, 0, 0, 57, 796000), '73', 'paid', None, None, 954, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  (2, datetime.datetime(2018, 11, 29, 0, 1, 30, 796000), '24', 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"'),
#  (3, datetime.datetime(2018, 11, 29, 0, 4, 1, 796000), '24', 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"'),
#  (4, datetime.datetime(2018, 11, 29, 0, 4, 55, 796000), '73', 'paid', None, None, 954, 'Tampa-St. Petersburg-Clearwater, FL', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  (5, datetime.datetime(2018, 11, 29, 0, 7, 13, 796000), '24', 'paid', None, None, 984, 'Lake Havasu City-Kingman, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')]

# %%
# %sql SELECT * FROM users LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('73', 'Jacob', 'Klein', 'M', 'paid'),
#  ('24', 'Layla', 'Griffin', 'F', 'paid'),
#  ('50', 'Ava', 'Robinson', 'F', 'free'),
#  ('54', 'Kaleb', 'Cook', 'M', 'free'),
#  ('32', 'Lily', 'Burns', 'F', 'free')]

# %%
# %sql SELECT * FROM songs LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('SOINLJW12A8C13314C', 'City Slickers', 'AR8IEZO1187B99055E', 2008, 149.86404),
#  ('SOGDBUF12A8C140FAA', 'Intro', 'AR558FS1187FB45658', 2003, 75.67628),
#  ('SORRZGD12A6310DBC3', 'Harajuku Girls', 'ARVBRGZ1187FB4675A', 2004, 290.55955),
#  ('SONWXQJ12A8C134D94', 'The Ballad Of Sleeping Beauty', 'ARNF6401187FB57032', 1994, 305.162),
#  ('SOFCHDR12AB01866EF', 'Living Hell', 'AREVWGE1187B9B890A', 0, 282.43546)]

# %%
# %sql SELECT * FROM artists LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [('AR8IEZO1187B99055E', 'Marc Shaiman', '', nan, nan),
#  ('AR558FS1187FB45658', '40 Grit', '', nan, nan),
#  ('ARVBRGZ1187FB4675A', 'Gwen Stefani', '', nan, nan),
#  ('ARNF6401187FB57032', 'Sophie B. Hawkins', 'New York, NY [Manhattan]', 40.79086, -73.96644),
#  ('AREVWGE1187B9B890A', 'Bitter End', 'Noci (BA)', -13.442, -41.9952)]

# %%
# %sql SELECT * FROM time LIMIT 5;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 5 rows affected.
# [(datetime.datetime(2018, 11, 29, 0, 0, 57, 796000), 0, 29, 48, 11, 2018, 3),
#  (datetime.datetime(2018, 11, 29, 0, 1, 30, 796000), 0, 29, 48, 11, 2018, 3),
#  (datetime.datetime(2018, 11, 29, 0, 4, 1, 796000), 0, 29, 48, 11, 2018, 3),
#  (datetime.datetime(2018, 11, 29, 0, 4, 55, 796000), 0, 29, 48, 11, 2018, 3),
#  (datetime.datetime(2018, 11, 29, 0, 7, 13, 796000), 0, 29, 48, 11, 2018, 3)]

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).
